# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from math import pi

# # Define the categories and the values for each year
# categories = ['Legal', 'Technical', 'Organizational', 'Capacity', 'Cooperative']
# values_2021 = [19.11, 15.57, 17.64, 16.84, 17.34]
# values_2024 = [20, 20, 19.22, 20, 20]

# # Number of variables we're plotting
# num_vars = len(categories)

# # Compute angle for each category on the radar chart
# angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
# angles += angles[:1]  # Complete the loop

# # Radar chart setup
# fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# # Plot data for 2021
# ax.plot(angles, values_2021 + values_2021[:1], linewidth=2, linestyle='solid', label=f'2021 (Total: {sum(values_2021)})')
# ax.fill(angles, values_2021 + values_2021[:1], alpha=0.4)

# # Plot data for 2024
# ax.plot(angles, values_2024 + values_2024[:1], linewidth=2, linestyle='solid', label=f'2024 (Total: {sum(values_2024)})')
# ax.fill(angles, values_2024 + values_2024[:1], alpha=0.4)

# # Add labels for each category
# ax.set_yticklabels([])  # Hide y-tick labels
# ax.set_xticks(angles[:-1])
# ax.set_xticklabels(categories, fontsize=15)  # Increase the font size of categories

# # Calculate differences between 2021 and 2024 and display them on the chart
# for i, (v2021, v2024, angle) in enumerate(zip(values_2021, values_2024, angles)):
#     difference = v2024 - v2021
#     ax.text(angle, max(v2021, v2024) + 4, f"{difference:+.2f}", 
#             horizontalalignment='left', size=12, color='black')

# # Add title and legend
# plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# # Show plot
# plt.tight_layout()
# plt.show()

# %%
# import numpy as np
# import matplotlib.pyplot as plt
# from math import pi

# # Define the categories and the values for each year
# categories = ['Legal', 'Technical', 'Organizational', 'Capacity', 'Cooperative']
# values_2021 = [19.11, 15.57, 17.64, 16.84, 17.34]
# values_2024 = [20, 20, 19.22, 20, 20]

# # Number of variables we're plotting
# num_vars = len(categories)

# # Compute angle for each category on the radar chart
# angles = [n / float(num_vars) * 2 * pi for n in range(num_vars)]
# angles += angles[:1]  # Complete the loop

# # Radar chart setup
# fig, ax = plt.subplots(figsize=(10, 10), subplot_kw=dict(polar=True))

# # Plot data for 2021
# ax.plot(angles, values_2021 + values_2021[:1], linewidth=2, linestyle='solid', label=f'2021 (Total: {sum(values_2021)})')
# ax.fill(angles, values_2021 + values_2021[:1], alpha=0.4)

# # Plot data for 2024
# ax.plot(angles, values_2024 + values_2024[:1], linewidth=2, linestyle='solid', label=f'2024 (Total: {sum(values_2024)})')
# ax.fill(angles, values_2024 + values_2024[:1], alpha=0.4)

# # Add labels for each category
# ax.set_yticklabels([])  # Hide y-tick labels
# ax.set_xticks(angles[:-1])
# ax.set_xticklabels(categories, fontsize=15)  # Increase the font size of categories

# # Calculate differences between 2021 and 2024 and display them on the chart
# # Define custom differences (e.g., for Technical)
# custom_differences = {
#     'Technical': "+4.43",  # Manually specified difference for 'Technical'
# }

# for i, (v2021, v2024, angle) in enumerate(zip(values_2021, values_2024, angles)):
#     difference = v2024 - v2021
#     label = custom_differences.get(categories[i], f"{difference:+.2f}")  # Use custom difference if available
#     ax.text(angle, max(v2021, v2024) + 4, f" ({label})", 
#             horizontalalignment='center', size=12, color='black')

# # Add title and legend
# plt.legend(loc='upper right', bbox_to_anchor=(0.1, 0.1))

# # Show plot
# plt.tight_layout()
# plt.show()

# %%
# pip install qrcode
# pip install "qrcode[pil]"

# %%
import qrcode

# Your website URL
url = 'https://github.com/Wwdwdws2334/HBD-project/blob/main/index.html'

# Generate QR code
qr = qrcode.QRCode(
    version=1,
    error_correction=qrcode.constants.ERROR_CORRECT_L,
    box_size=10,
    border=4,
)
qr.add_data(url)
qr.make(fit=True)

# Create an image from the QR code
img = qr.make_image(fill='black', back_color='white')
img.save('/Users/latthawat/Desktop/HBD project/birthday_qr_code.png')
